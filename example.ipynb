# %% [markdown]
# <a href="https://colab.research.google.com/github/aimuxlisa/week1-lab/blob/main/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Please update the information, and submit your work

# %%
my_name = "Muxlisa Xaydarova"

# %%
my_enrollment_number = "A123456789"

# %%
my_hobby = "Badmiton, watching dorama"

# %%
print("Hello, my name is {}, and my my enrollment number is {}. I like {}.".format(my_name, my_enrollment_number, my_hobby))
